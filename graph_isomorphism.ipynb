# %% [markdown]
# # **Graph Isomorphism - Matthew Corcoran**

# %% [markdown]
# **Student Number** : G00385842

# %% [markdown]
# # **Introduction**
#
# This juypter notebook is to deminstrate and explian the graph isomorpism problem.
# The goal of this book is to help the reader understand basic definitions and give the reader a good understanding of the graph isomorphism problem.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # **Graphs**
# In discrete mathematics, a graph is a collection of points, called vertices, and lines between those points, called edges. There are many different types of graphs, such as connected and disconnected graphs, bipartite graphs, weighted graphs, directed and undirected graphs, and simple graphs.
# Reference: https://study.com/

# %%
G = nx.grid_2d_graph(3,3)
plt.figure(figsize=(6,6))
pos = {(x,y):(y,-x) for x,y in G.nodes()}
nx.draw(G, pos=pos, node_color='lightgreen',  node_size=600)

# %% [markdown]
# # **Point**
# A point on a graph is a static postion on the graph.
# The point is usually represted with a x and a y value eg.(2,3).

# %%
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.xlim(0, 5)
plt.ylim(0, 5)
plt.grid()

plt.plot(2, 3, marker="o", markersize=20)
plt.show()

# %% [markdown]
# # **Line**
#
# a line connects any two vertices representing objects that are related or adjacent;
#
# reference: http://web.math.princeton.edu/math_alive/5/Lab1/Defs.html#:~:text=A%20graph%20is%20a%20slightly,line%20is%20called%20an%20edge.

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
pA = [1, 4]
pB = [3, 4]
x_values = [pA[0], pB[0]]
y_values = [pA[1], pB[1]]
plt.plot(x_values, y_values, 'bo', linestyle="-")
plt.text(pA[0]-0.015, pA[1]+0.25, "")
plt.text(pB[0]-0.050, pB[1]-0.25, "")
plt.show()

# %% [markdown]
# # **vertex**
# a vertex (plural vertices) or node is the fundamental unit of which graphs are formed: an undirected graph consists of a set of vertices and a set of edges (unordered pairs of vertices), while a directed graph consists of a set of vertices and a set of arcs (ordered pairs of vertices). In a diagram of a graph, a vertex is usually represented by a circle with a label, and an edge is represented by a line or arrow extending from one vertex to another.
#
# reference : https://en.wikipedia.org/wiki/Vertex_(graph_theory)

# %% [markdown]
# # **Edge**
# An edge of a graph is one of the connections between the nodes of the network. Edges can be directed, meaning they point from one node to the next.
#
# reference : https://mathinsight.org/definition/network_edge#:~:text=An%20edge%20(or%20link)%20of,in%20the%20first%20figure%20below.

# %% [markdown]
# # **What is isomorphic**
# The isomorphism graph can be described as a graph in which a single graph can have more than one form. That means two different graphs can have the same number of edges, vertices, and same edges connectivity. These types of graphs are known as isomorphism graphs
#
# reference : https://www.javatpoint.com/graph-isomorphism-in-discrete-mathematics

# %%
G = nx.Graph()
G.add_edge(1, 2)
G.add_edge(1, 3)
G.add_edge(1, 5)
G.add_edge(2, 3)
G.add_edge(3, 4)
G.add_edge(4, 5)

pos = {1: (0, -1), 2: (-1, 0.3), 3: (2, 0.5), 4: (4, 0.255), 5: (5, -1)}
nx.draw_networkx(G, pos)

ax = plt.gca()
ax.margins(0.20)
plt.axis("off")
plt.show()



G = nx.Graph()
G.add_edge(1, 2)
G.add_edge(1, 3)
G.add_edge(1, 5)
G.add_edge(2, 3)
G.add_edge(3, 4)
G.add_edge(4, 5)

pos = {1: (0, 0), 2: (0, 0.8), 3: (2, 0), 4: (2, 0.5), 5: (2, 0.8)}
nx.draw_networkx(G, pos)

ax = plt.gca()
ax.margins(0.20)
plt.axis("off")
plt.show()

# %% [markdown]
# The following example above show to graphs that are isomorpic
