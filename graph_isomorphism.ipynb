# %% [markdown]
# # **Graph Isomorphism - Matthew Corcoran**

# %% [markdown]
# **Student Number** : G00385842

# %% [markdown]
# # **What is Graph Theroy**
#
# A Graph is a set of vertices(Points) and edges(Lines) that connect the vertices.
# This Requires two vertices that are joined by more than one line.

# %% [markdown]
# # **What is a point**
#
# A point on a graph is a static postion on the graph.
# The point is usually represted with a x and a y value eg.(2,3).

# %%
import matplotlib.pyplot as plt
import networkx as ne

# %%
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.xlim(0, 5)
plt.ylim(0, 5)
plt.grid()

plt.plot(2, 3, marker="o", markersize=20)
plt.show()

# %% [markdown]
# Lines

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
pA = [1, 4]
pB = [3, 4]
x_values = [pA[0], pB[0]]
y_values = [pA[1], pB[1]]
plt.plot(x_values, y_values, 'bo', linestyle="-")
plt.text(pA[0]-0.015, pA[1]+0.25, "")
plt.text(pB[0]-0.050, pB[1]-0.25, "")
plt.show()
