# %% [markdown]
# # **Graph Isomorphism - Matthew Corcoran**

# %% [markdown]
# **Student Number** : G00385842

# %% [markdown]
# # **Introduction**
#
# This juypter notebook is to deminstrate and explian the graph isomorpism problem.
# The goal of this book is to help the reader understand basic definitions and give the reader a good understanding of the graph isomorphism problem.
#
# In this notbook we will break dowm the componets of a graph and explain the in there simpler term with hope of giving the reader a better understanfing of the componets of a graph.
#
# Then we will talk about the graph ismorophism problem and the apllications that the problem has in real world application and how they are use in that area.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # **Graphs**
# A graph is deterined as a mathematical structure. A graph represents a function by connecting a set of points. A graph consits of vertices that are connected by edges.
#
#
# Example below shows a graph with nodes and vertices. The following examples below the graph will explain each component in the graph in basic terms with the goal of giving the reader a better understanding of the structer of a graph.
#
# Reference: https://study.com/

# %%
G = nx.complete_graph(4)
nx.draw(G)

# %% [markdown]
# # **Point**
# A point on a graph is a static postion on the graph.
# The point is usually represted with a x and a y position on the graph eg.(2,3).

# %%
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.xlim(0, 5)
plt.ylim(0, 5)
plt.grid()

plt.plot(2, 3, marker="o", markersize=20)
plt.show()

# %% [markdown]
# # **Line**
#
# A line connects to two vertices on the graph. A line represents the edge of a graph.

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
pA = [1, 4]
pB = [3, 4]
x_values = [pA[0], pB[0]]
y_values = [pA[1], pB[1]]
plt.plot(x_values, y_values, 'bo', linestyle="-")
plt.text(pA[0]-0.015, pA[1]+0.25, "")
plt.text(pB[0]-0.050, pB[1]-0.25, "")
plt.show()

# %% [markdown]
# # **vertex**
# A vertext(Node) are a set of points on a graph that are connected to eachother by egdes(lines).
#
# reference : https://en.wikipedia.org/wiki/Vertex_(graph_theory)

# %% [markdown]
# # **Edge**
# An edge of a graph is one of the connections between the nodes of the network. Edges can be directed, meaning they point from one node to the next.
#
# reference : https://mathinsight.org/definition/network_edge#:~:text=An%20edge%20(or%20link)%20of,in%20the%20first%20figure%20below.

# %% [markdown]
# # **What is isomorphism**
# The isomorphism graph can be described as a graph in which a single graph can have more than one form. That means two different graphs can have the same number of edges, vertices, and same edges connectivity. These types of graphs are known as isomorphism graphs
#
# A graph cannot be isomorphic if the 2 graphs have a differnet about of egdes or vertices. in other term both of the graphs have to have the same amount of nodes and connextions to the nodes to be isomorphic.
#
# reference : https://www.javatpoint.com/graph-isomorphism-in-discrete-mathematics

# %%
G = nx.Graph()
G.add_edge(1, 2)
G.add_edge(1, 3)
G.add_edge(1, 5)
G.add_edge(2, 3)
G.add_edge(3, 4)
G.add_edge(4, 5)

pos = {1: (0, -1), 2: (-1, 0.3), 3: (2, 0.5), 4: (4, 0.255), 5: (5, -1)}
nx.draw_networkx(G, pos)

ax = plt.gca()
ax.margins(0.20)
plt.axis("off")
plt.show()



G = nx.Graph()
G.add_edge(1, 2)
G.add_edge(1, 3)
G.add_edge(1, 5)
G.add_edge(2, 3)
G.add_edge(3, 4)
G.add_edge(4, 5)

pos = {1: (0, 0), 2: (0, 0.8), 3: (2, 0), 4: (2, 0.5), 5: (2, 0.8)}
nx.draw_networkx(G, pos)

ax = plt.gca()
ax.margins(0.20)
plt.axis("off")
plt.show()

# %% [markdown]
# The following example above show to graphs that are isomorpic
# The reason the teo following graph are iosomorphic is because both graphs consist of 5 edges(lines) connect to 5 vertices(Nodes)
# and because 5 vertices(nodes) are connect by 5 edges(lines).
#
# for example if g1 had 4 vertices(nodes) with 4 edges(Lines) and g2 had 3 vertices and 4 edges the graph could not be isomorphic because the structer of the two graphs a completely different.

# %% [markdown]
# # **The Graph Isomorphism Problem**

# %% [markdown]
# The Graph isomorphism Problem is a computational problem of determining whether two graphs that are visually different are structurly the same or isomorphic.The Graph isomorphism problem has been studied sine the early years id computing.The Graph isomorphism problem is all about symmetry and reqularity.
#
# The graph isomorphism problem is not know to be solvable in polynomail time nor to be NP-complete. The complexity of the graph ismorphism is unknown the problem at face seem to be very easy comparing to graphs to see if they are structurly the same but the problem is still unsolved.
#
# in simple term the graph isomorphis is to see if two graphs have the same amount of vertex and nodes.
#
# references : https://people.cs.uchicago.edu/~laci/papers/icm18-babai.pdf
#
# https://cacm.acm.org/magazines/2020/11/248220-the-graph-isomorphism-problem/abstract
#
# https://en.wikipedia.org/wiki/Graph_isomorphism_problem

# %% [markdown]
# # **Matrices**
#
# Computers are better a computing number rather that images. which is one on the main reasons it is common reasons to communicate the specification of a graph to a computer in matrix form. There are two main to communicate in matrix for these are adjacency matrices and incidence matrices.
#
# reference : https://towardsdatascience.com/graph-theory-set-matrix-notation-7dfb04b8ed24

# %% [markdown]
# **Adjacency Matrix**
#
# A Adjaceny matrix also called a connection matrix of a labeled graph is a matric with rows and colums labeled by the graph vertices, with 1 or 0 in postion(L1,L2)
# according to whether l1 and l2 are adjecent or not.
#
# reference : https://mathworld.wolfram.com/AdjacencyMatrix.html

# %%
G = nx.Graph([(1, 10)])
A = nx.adjacency_matrix(G)
print(A.todense())
[[1]]
A.setdiag(A.diagonal() * 2)
print(A.todense())
# Out:
# [[0 1]
#  [1 0]]
# [[0 1]
#  [1 0]]
# C:\Users\User\AppData\Local\Temp\ipykernel_9784\5722271.py:2: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   A = nx.adjacency_matrix(G)

# %% [markdown]
# **incidence Matrix**
#
# A incidence matric of a graph give the (0,1) matrix which has a row for each vertex(node) and column for edge(line).
#
# reference : https://mathworld.wolfram.com/IncidenceMatrix.html

# %%
G = nx.Graph([(1, 10)])
A = nx.incidence_matrix(G)
print(A.todense())
[[1]]
A.setdiag(A.diagonal() * 2)
print(A.todense())
# Out:
# [[1.]
#  [1.]]
# [[2.]
#  [1.]]
# C:\Users\User\AppData\Local\Temp\ipykernel_9784\860818601.py:2: FutureWarning: incidence_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   A = nx.incidence_matrix(G)

# %% [markdown]
# # **Applications of Graph Isomorphism**
#
# Graph isomorphis has many real world apllications in the world.
#
# it can be used to compare two images. i can also be used to find defects in images such as texture defects within a image.
#
# it also has a use in the secuity industry such as facial and fingerprint scanners. for example once a person scans the face or fingerprint the proccess would be much the same as a graph ismorphism to see if the face or fingerprint are the same.
#
# cryptographs(zero-knowledge proofs)
# A zero knowlegde proof allows you to prove whether a statement is true or false without ever sharing or revealing the statements contents.
#
# Automata theory it has multiple uses but it mainly used to prove that two lanugages are the same or equal
#
# reference : https://ethereum.org/en/zero-knowledge-proofs/
